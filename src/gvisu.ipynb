# %%
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../Metropolis/')
sys.path.append('..')

from networkGenerator import flattenIncomingDegree, getSBM, makeColumnStochastic, getDirectedErdosRenyi, \
sumColumns, randomDegreeSequence, fixedDegreeSequence, \
getDirectedConfigurationModel, flattenIncomingDegree

# %%
from gvisu import drawMatrix, drawCurvedEdgesGraph

# %%
sizes = [30,30,40]
ps = [[0.5, 0.05, 0.02], 
        [0.05, 0.5, 0.07], 
        [0.02, 0.07, 0.5]]

g = getSBM(sizes, ps)

# %%
drawMatrix(g=g, experiment_title='test_ex1')

# %%
g2 = makeColumnStochastic(g, with_random_weights_initialization=True)

# %%
drawMatrix(g=g2, experiment_title='test_ex2', folder='../data')

# %%
drawCurvedEdgesGraph(g2)
